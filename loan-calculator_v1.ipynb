# %% [markdown]
# # Loan calculator

# %% [markdown]
# ## Imports

# %%
# For all functions
import numpy as np

# For graphs
import matplotlib.pyplot as plt
# %matplotlib inline


# For table formatting
import locale 
from tabulate import tabulate

# %% [markdown]
# ## Functions

# %%
def PMT(c:int =1000, r:float=1.0, per:int=1, fper:int=1):
    """ Calculate the payment for a loan based on constant payments and a constant interest rate.
    Args:
        - c (int) : capital or Present Value
        - r (float) : Annual Rate in decimal format (ex : 0.03 for 3%)
        - fper (int) : fraction of period of interest periods per year
        - per (int) : number of years
    Returns:
        float: PMT value
    """
    nper = per * fper # number of periodic payment
    pir = r / fper # Periodic Interest Rate
    PMT = (c * pir) / (1 - (1 + pir)**(-nper))

    return -PMT



def IPMT(pmt:float, r:float, per:int, fper:int, c:int):    
    """ Calculate IPMT
    Args:
        - pmt (float) : PMT()
        - r (float) : Annual Rate in decimal format (ex : 0.03 for 3%)
        - per (int) : Payment Number
        - fper (int) : fraction of period of interest periods per year
        - c (int) : capital or Present Value
    Returns:
        float: IPMT value
    """
     
    pir = r / fper # Periodic Interest Rate
    
    
    IPMT = -(pmt * ((1 + pir)**(per-1) - 1) / pir + c * (1 + pir)**(per-1)) * pir

    return IPMT


def PPMT(pmt:float, r:float, per:int, fper:int, c:int):
    """ Calculate PPMT
    Args:
        - pmt (float) : PMT()
        - r (float) : Annual Rate in decimal format (ex : 0.03 for 3%)
        - per (int) : Payment Number
        - fper (int) : fraction of period of interest periods per year
        - c (int) : Present Value
    Returns:
        float: PPMT value
    """
    
    pir = r / fper # Periodic Interest Rate
    
    ppmt = pmt+(pmt * ((1 + pir)**(per-1) - 1) / pir + c * (1 + pir)**(per-1)) * pir

    return ppmt


def loan_calculation(c:int, r:float, per:int, fper:int):
    """ Calculate the depreciation schedule
    Args:
        - c (int) : PMT()
        - r (float) : Annual Rate in decimal format (ex : 0.03 for 3%)
        - per (int) : Payment Number
        - fper (fper) : fraction of period of interest periods per year
    Returns:
        list_per, list_ipmt, list_ppmt, list_pmt : list of periods, interest, capital and payment
    """
    
    pmt = PMT(c=c, r=r, per=per, fper=fper ) 
    
    nper = per * fper # number of periodic payment
    
    list_per = []
    list_ipmt = []
    list_ppmt = []
    list_pmt = []
    
    for i in range(nper):
        
        ipmt = IPMT(pmt=pmt, r=r, per=i, fper=fper, c=c) 
        ppmt = PPMT(pmt=pmt, r=r, per=i, fper=fper, c=c) 
        
        list_per.append(i +1) # To start from period 1 instead of zero
        list_ipmt.append(-ipmt)
        list_ppmt.append(-ppmt)
        list_pmt.append(-pmt)
    
    return list_per, list_ipmt, list_ppmt, list_pmt


def find_per_cumul_interest(per:list, ipmt:list, threshold:float=0.5):
    """ Return the period number corresponding a cumulated target value

    Args:
        - per (list): list of period
        - ipmt (list): list of periodic interest
        - threshold (float, optional): share of interests already paid (cumulative). Defaults to 0.5.

    Returns:
        int: period when cumulated interest goes beyond the threshold
    """
    
    ipmt_target = np.sum(ipmt) * threshold
    ipmt_cum = np.cumsum(ipmt)
    
    for p, i in zip(per, ipmt_cum):
        
        if i > ipmt_target:
            return p
            break
        
        

def unformated_depreciation_table(per:list, ipmt:list, ppmt:list, pmt:list):
    """ Return a semi-formated depreciation schedule

    Args:
        - per (list): list of periods
        - ipmt (list): list of periodic interests
        - ppmt (list): list of periodic capital
        - pmt (list): list of periodic payments

    Returns:
        list: return a formated table
    """
    
    # To use default Operating Système regional settings
    locale.setlocale(locale.LC_ALL, '')
    
    # Headers
    headers_FR = ["Echéance", "Mensualité\néchéance", "Capital\néchéance", "Intérêts\néchéance", "Capital\ncumulé", "Intérêts\ncumulé", "Capital\nrestant", "Intérêts\nrestants"]
    headers_ENG = ["Period", "Payment\nPeriodic", "Principal\nPeriodic", "Interest\nPeriodic", "Principal\nCumulated", "Interest\nCumulated", "Principal\nremaining", "Interest\nremaining"]

    
    # Initialization of the list
    loan_table = []

    
    # Loop
    for i in range(1, max(per) ):
        
        periodic_payment = pmt[i]
        principal_periodic = ppmt[i]
        interest_periodic = ipmt[i]
        principal_cumulated = np.sum(ppmt[:i+1])
        interest_cumulated = np.sum(ipmt[:i+1])
        principal_remaining = np.sum(ppmt) - principal_cumulated
        interest_remaining = np.sum(ipmt) - interest_cumulated

        # Built of the periodic line
        periodic_line = [
            i, 
            locale._format('%.2f', periodic_payment ),
            locale._format('%.2f', principal_periodic ),
            locale._format('%.2f', interest_periodic ),
            locale._format('%.2f', principal_cumulated ),
            locale._format('%.2f', interest_cumulated ),
            locale._format('%.2f', principal_remaining ),
            locale._format('%.2f', interest_remaining )
            ]
    
        # Add of the periodic line inside the table
        loan_table.append(periodic_line)
    
    print(tabulate(loan_table, headers = headers_FR, tablefmt="fancy_grid"))
    
    return loan_table


def formated_depreciation_table(per:list, ipmt:list, ppmt:list, pmt:list, table_size:int=12):
    """ Return a formated depreciation schedule

    Args:
        - per (list): list of periods
        - ipmt (list): list of periodic interests
        - ppmt (list): list of periodic capital
        - pmt (list): list of periodic payments
        - table_size (int, optional): number of periods used to split the table. Defaults to 12.

    Returns:
        table: formated depreciation table
    """
    
    # To use default Operating Système regional settings
    locale.setlocale(locale.LC_ALL, '')
    
    # Headers
    headers_FR = ["Echéance", "Mensualité\néchéance", "Capital\néchéance", "Intérêts\néchéance", "Capital\ncumulé", "Intérêts\ncumulé", "Capital\nrestant", "Intérêts\nrestants"]
    headers_ENG = ["Period", "Payment\nPeriodic", "Principal\nPeriodic", "Interest\nPeriodic", "Principal\nCumulated", "Interest\nCumulated", "Principal\nremaining", "Interest\nremaining"]

    
    # First Initialization of the list
    loan_table = []

    # Table size definition
    list_per_cut = np.arange(0, np.max(per), table_size)
    period_start = 0
    period_end = 0
    
    # Loop
    for i in range(min(per), max(per) ):
        
        period_start=period_end
        
        periodic_payment = pmt[i]
        principal_periodic = ppmt[i]
        interest_periodic = ipmt[i]
        principal_cumulated = np.sum(ppmt[:i+1])
        interest_cumulated = np.sum(ipmt[:i+1])
        principal_remaining = np.sum(ppmt) - principal_cumulated
        interest_remaining = np.sum(ipmt) - interest_cumulated

        # Built of the periodic line
        periodic_line = [
            i, 
            locale._format('%.2f', periodic_payment ),
            locale._format('%.2f', principal_periodic ),
            locale._format('%.2f', interest_periodic ),
            locale._format('%.2f', principal_cumulated ),
            locale._format('%.2f', interest_cumulated ),
            locale._format('%.2f', principal_remaining ),
            locale._format('%.2f', interest_remaining )
            ]
          
        if not i in list_per_cut:

            # Add of the periodic line inside the table
            loan_table.append(periodic_line)
            
            
        if i in list_per_cut:
            
            period_end = i
            
            # Add of the periodic line inside the table
            loan_table.append(periodic_line)

            print(tabulate(loan_table, headers = headers_FR, tablefmt="fancy_grid"))
            print("Total périodes : ",period_start, " - ", period_end, '-' * 78)
            print("Capital cumulé : ", locale._format('%.2f', principal_cumulated ))
            print("Intérêts cumulés : ", locale._format('%.2f', interest_cumulated ))
            print('-' * 105)
            print(" ")
            
            loan_table = []

    return "End"

# %% [markdown]
# ## Global Variables

# %%
c1 = 100000 # Capital
r1 = 0.0300 # Annual Interest rate
fper1 = 12 # Number of periodic payments (number of months per year)
per1 = 25 # Number of years 
n1 = 300 # Specific period

# %% [markdown]
# ## Loan calculation

# %%
pmt1 = PMT(c=c1, r=r1, per=per1, fper=fper1 ) 
ipmt1 = IPMT(pmt=pmt1, r=r1, per=n1, fper=fper1, c=c1) 
ppmt1 = PPMT(pmt=pmt1, r=r1, per=n1, fper=fper1, c=c1) 

print( pmt1 )
print( ipmt1)
print( ppmt1 )
# Out:
# -474.21131385767984
# -1.1825718550066087
# -473.02874200267325

# %%
list_per, list_ipmt, list_ppmt, list_pmt = loan_calculation(c=c1, r=r1, per=per1, fper=fper1)

# Display samples
print('Last period number : ', max(list_per))
print('3 firsts periods numbers : ', list_per[:3])
print('3 lasts periods numbers : ', list_per[-3:])
print('3 firsts periodic payments : ', list_pmt[:3])
print('3 lasts periodic payments : ', list_pmt[-3:])
print('3 firsts periodic interest : ', list_ipmt[:3])
print('3 lasts periodic interest : ', list_ipmt[-3:])
print('3 firsts periodic principal : ', list_ppmt[:3])
print('3 lasts periodic principal : ', list_ppmt[-3:])
print('Total payments : ', np.sum(list_pmt))
print('Total interest : ', np.sum(list_ipmt))
print('Total principal : ', np.sum(list_ppmt))
# Out:
# Last period number :  300
# 3 firsts periods numbers :  [1, 2, 3]
# 3 lasts periods numbers :  [298, 299, 300]
# 3 firsts periodic payments :  [474.21131385767984, 474.21131385767984, 474.21131385767984]
# 3 lasts periodic payments :  [474.21131385767984, 474.21131385767984, 474.21131385767984]
# 3 firsts periodic interest :  [250.55913045849795, 250.0, 249.43947171535584]
# 3 lasts periodic interest :  [4.712622476744072, 3.5388757482916846, 2.362194653018232]
# 3 firsts periodic principal :  [223.6521833991819, 224.21131385767984, 224.771842142324]
# 3 lasts periodic principal :  [469.4986913809358, 470.67243810938817, 471.84911920466163]
# Total payments :  142263.39415730393
# Total interest :  42512.77071590531
# Total principal :  99750.62344139864

# %% [markdown]
# ## Loan Formatting

# %%
# unformated_depreciation_table(per=list_per, ipmt=list_ipmt, ppmt=list_ppmt, pmt=list_pmt)
formated_depreciation_table(per=list_per, ipmt=list_ipmt, ppmt=list_ppmt, pmt=list_pmt, table_size=12)
# Out:
# ╒════════════╤══════════════╤════════════╤════════════╤═══════════╤════════════╤═══════════╤════════════╕
# │   Echéance │ Mensualité   │ Capital    │ Intérêts   │ Capital   │ Intérêts   │ Capital   │ Intérêts   │
# │            │ échéance     │ échéance   │ échéance   │ cumulé    │ cumulé     │ restant   │ restants   │
# ╞════════════╪══════════════╪════════════╪════════════╪═══════════╪════════════╪═══════════╪════════════╡
# │          1 │ 474,21       │ 224,21     │ 250,00     │ 447,86    │ 500,56     │ 99302,76  │ 42012,21   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │          2 │ 474,21       │ 224,77     │ 249,44     │ 672,64    │ 750,00     │ 99077,99  │ 41762,77   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │          3 │ 474,21       │ 225,33     │ 248,88     │ 897,97    │ 998,88     │ 98852,65  │ 41513,89   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │          4 │ 474,21       │ 225,90     │ 248,31     │ 1123,87   │ 1247,19    │ 98626,76  │ 41265,58   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │          5 │ 474,21       │ 226,46     │ 247,75     │ 1350,33   │ 1494,94    │ 98400,30  │ 41017,83   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │          6 │ 474,21       │ 227,03     │ 247,18     │ 1577,36   │ 1742,12    │ 98173,27  │ 40770,65   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │          7 │ 474,21       │ 227,60     │ 246,62     │ 1804,95   │ 1988,74    │ 97945,67  │ 40524,03   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │          8 │ 474,21       │ 228,16     │ 246,05     │ 2033,12   │ 2234,79    │ 97717,51  │ 40277,99   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │          9 │ 474,21       │ 228,73     │ 245,48     │ 2261,85   │ 2480,26    │ 97488,77  │ 40032,51   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         10 │ 474,21       │ 229,31     │ 244,90     │ 2491,16   │ 2725,17    │ 97259,47  │ 39787,60   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         11 │ 474,21       │ 229,88     │ 244,33     │ 2721,04   │ 2969,50    │ 97029,59  │ 39543,27   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         12 │ 474,21       │ 230,45     │ 243,76     │ 2951,49   │ 3213,25    │ 96799,13  │ 39299,52   │
# ╘════════════╧══════════════╧════════════╧════════════╧═══════════╧════════════╧═══════════╧════════════╛
# Total périodes :  0  -  12 ------------------------------------------------------------------------------
# Capital cumulé :  2951,49
# Intérêts cumulés :  3213,25
# ---------------------------------------------------------------------------------------------------------
#
# ╒════════════╤══════════════╤════════════╤════════════╤═══════════╤════════════╤═══════════╤════════════╕
# │   Echéance │ Mensualité   │ Capital    │ Intérêts   │ Capital   │ Intérêts   │ Capital   │ Intérêts   │
# │            │ échéance     │ échéance   │ échéance   │ cumulé    │ cumulé     │ restant   │ restants   │
# ╞════════════╪══════════════╪════════════╪════════════╪═══════════╪════════════╪═══════════╪════════════╡
# │         13 │ 474,21       │ 231,03     │ 243,18     │ 3182,52   │ 3456,43    │ 96568,10  │ 39056,34   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         14 │ 474,21       │ 231,61     │ 242,60     │ 3414,13   │ 3699,04    │ 96336,49  │ 38813,73   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         15 │ 474,21       │ 232,19     │ 242,02     │ 3646,32   │ 3941,06    │ 96104,30  │ 38571,71   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         16 │ 474,21       │ 232,77     │ 241,44     │ 3879,09   │ 4182,50    │ 95871,54  │ 38330,27   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         17 │ 474,21       │ 233,35     │ 240,86     │ 4112,44   │ 4423,37    │ 95638,19  │ 38089,40   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         18 │ 474,21       │ 233,93     │ 240,28     │ 4346,37   │ 4663,64    │ 95404,25  │ 37849,13   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         19 │ 474,21       │ 234,52     │ 239,69     │ 4580,89   │ 4903,34    │ 95169,73  │ 37609,43   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         20 │ 474,21       │ 235,10     │ 239,11     │ 4815,99   │ 5142,44    │ 94934,63  │ 37370,33   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         21 │ 474,21       │ 235,69     │ 238,52     │ 5051,69   │ 5380,96    │ 94698,94  │ 37131,81   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         22 │ 474,21       │ 236,28     │ 237,93     │ 5287,97   │ 5618,89    │ 94462,66  │ 36893,88   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         23 │ 474,21       │ 236,87     │ 237,34     │ 5524,84   │ 5856,23    │ 94225,78  │ 36656,54   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         24 │ 474,21       │ 237,46     │ 236,75     │ 5762,30   │ 6092,98    │ 93988,32  │ 36419,79   │
# ╘════════════╧══════════════╧════════════╧════════════╧═══════════╧════════════╧═══════════╧════════════╛
# Total périodes :  12  -  24 ------------------------------------------------------------------------------
# Capital cumulé :  5762,30
# Intérêts cumulés :  6092,98
# ---------------------------------------------------------------------------------------------------------
#
# ╒════════════╤══════════════╤════════════╤════════════╤═══════════╤════════════╤═══════════╤════════════╕
# │   Echéance │ Mensualité   │ Capital    │ Intérêts   │ Capital   │ Intérêts   │ Capital   │ Intérêts   │
# │            │ échéance     │ échéance   │ échéance   │ cumulé    │ cumulé     │ restant   │ restants   │
# ╞════════════╪══════════════╪════════════╪════════════╪═══════════╪════════════╪═══════════╪════════════╡
# │         25 │ 474,21       │ 238,06     │ 236,15     │ 6000,36   │ 6329,13    │ 93750,26  │ 36183,64   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         26 │ 474,21       │ 238,65     │ 235,56     │ 6239,01   │ 6564,69    │ 93511,61  │ 35948,08   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         27 │ 474,21       │ 239,25     │ 234,96     │ 6478,26   │ 6799,65    │ 93272,36  │ 35713,12   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         28 │ 474,21       │ 239,85     │ 234,36     │ 6718,11   │ 7034,02    │ 93032,51  │ 35478,75   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         29 │ 474,21       │ 240,45     │ 233,76     │ 6958,56   │ 7267,78    │ 92792,06  │ 35244,99   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         30 │ 474,21       │ 241,05     │ 233,16     │ 7199,61   │ 7500,94    │ 92551,02  │ 35011,83   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         31 │ 474,21       │ 241,65     │ 232,56     │ 7441,26   │ 7733,50    │ 92309,36  │ 34779,27   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         32 │ 474,21       │ 242,26     │ 231,96     │ 7683,51   │ 7965,46    │ 92067,11  │ 34547,31   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         33 │ 474,21       │ 242,86     │ 231,35     │ 7926,38   │ 8196,81    │ 91824,25  │ 34315,96   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         34 │ 474,21       │ 243,47     │ 230,74     │ 8169,84   │ 8427,55    │ 91580,78  │ 34085,22   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         35 │ 474,21       │ 244,08     │ 230,13     │ 8413,92   │ 8657,69    │ 91336,70  │ 33855,08   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         36 │ 474,21       │ 244,69     │ 229,52     │ 8658,61   │ 8887,21    │ 91092,02  │ 33625,56   │
# ╘════════════╧══════════════╧════════════╧════════════╧═══════════╧════════════╧═══════════╧════════════╛
# Total périodes :  24  -  36 ------------------------------------------------------------------------------
# Capital cumulé :  8658,61
# Intérêts cumulés :  8887,21
# ---------------------------------------------------------------------------------------------------------
#
# ╒════════════╤══════════════╤════════════╤════════════╤═══════════╤════════════╤═══════════╤════════════╕
# │   Echéance │ Mensualité   │ Capital    │ Intérêts   │ Capital   │ Intérêts   │ Capital   │ Intérêts   │
# │            │ échéance     │ échéance   │ échéance   │ cumulé    │ cumulé     │ restant   │ restants   │
# ╞════════════╪══════════════╪════════════╪════════════╪═══════════╪════════════╪═══════════╪════════════╡
# │         37 │ 474,21       │ 245,30     │ 228,91     │ 8903,91   │ 9116,12    │ 90846,72  │ 33396,65   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         38 │ 474,21       │ 245,91     │ 228,30     │ 9149,82   │ 9344,42    │ 90600,81  │ 33168,35   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         39 │ 474,21       │ 246,53     │ 227,68     │ 9396,34   │ 9572,11    │ 90354,28  │ 32940,66   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         40 │ 474,21       │ 247,14     │ 227,07     │ 9643,49   │ 9799,18    │ 90107,14  │ 32713,59   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         41 │ 474,21       │ 247,76     │ 226,45     │ 9891,25   │ 10025,63   │ 89859,37  │ 32487,14   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         42 │ 474,21       │ 248,38     │ 225,83     │ 10139,63  │ 10251,46   │ 89610,99  │ 32261,31   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         43 │ 474,21       │ 249,00     │ 225,21     │ 10388,63  │ 10476,67   │ 89361,99  │ 32036,10   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         44 │ 474,21       │ 249,62     │ 224,59     │ 10638,25  │ 10701,26   │ 89112,37  │ 31811,52   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         45 │ 474,21       │ 250,25     │ 223,96     │ 10888,50  │ 10925,22   │ 88862,12  │ 31587,55   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         46 │ 474,21       │ 250,87     │ 223,34     │ 11139,38  │ 11148,56   │ 88611,25  │ 31364,21   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         47 │ 474,21       │ 251,50     │ 222,71     │ 11390,88  │ 11371,27   │ 88359,75  │ 31141,50   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         48 │ 474,21       │ 252,13     │ 222,08     │ 11643,01  │ 11593,35   │ 88107,62  │ 30919,42   │
# ╘════════════╧══════════════╧════════════╧════════════╧═══════════╧════════════╧═══════════╧════════════╛
# Total périodes :  36  -  48 ------------------------------------------------------------------------------
# Capital cumulé :  11643,01
# Intérêts cumulés :  11593,35
# ---------------------------------------------------------------------------------------------------------
#
# ╒════════════╤══════════════╤════════════╤════════════╤═══════════╤════════════╤═══════════╤════════════╕
# │   Echéance │ Mensualité   │ Capital    │ Intérêts   │ Capital   │ Intérêts   │ Capital   │ Intérêts   │
# │            │ échéance     │ échéance   │ échéance   │ cumulé    │ cumulé     │ restant   │ restants   │
# ╞════════════╪══════════════╪════════════╪════════════╪═══════════╪════════════╪═══════════╪════════════╡
# │         49 │ 474,21       │ 252,76     │ 221,45     │ 11895,77  │ 11814,80   │ 87854,86  │ 30697,97   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         50 │ 474,21       │ 253,39     │ 220,82     │ 12149,16  │ 12035,62   │ 87601,47  │ 30477,15   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         51 │ 474,21       │ 254,03     │ 220,19     │ 12403,18  │ 12255,81   │ 87347,44  │ 30256,96   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         52 │ 474,21       │ 254,66     │ 219,55     │ 12657,84  │ 12475,36   │ 87092,78  │ 30037,41   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         53 │ 474,21       │ 255,30     │ 218,91     │ 12913,14  │ 12694,27   │ 86837,48  │ 29818,50   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         54 │ 474,21       │ 255,94     │ 218,28     │ 13169,07  │ 12912,55   │ 86581,55  │ 29600,22   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         55 │ 474,21       │ 256,57     │ 217,64     │ 13425,65  │ 13130,19   │ 86324,97  │ 29382,59   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         56 │ 474,21       │ 257,22     │ 217,00     │ 13682,86  │ 13347,18   │ 86067,76  │ 29165,59   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         57 │ 474,21       │ 257,86     │ 216,35     │ 13940,72  │ 13563,53   │ 85809,90  │ 28949,24   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         58 │ 474,21       │ 258,50     │ 215,71     │ 14199,23  │ 13779,24   │ 85551,40  │ 28733,53   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         59 │ 474,21       │ 259,15     │ 215,06     │ 14458,38  │ 13994,30   │ 85292,25  │ 28518,47   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         60 │ 474,21       │ 259,80     │ 214,41     │ 14718,18  │ 14208,71   │ 85032,45  │ 28304,06   │
# ╘════════════╧══════════════╧════════════╧════════════╧═══════════╧════════════╧═══════════╧════════════╛
# Total périodes :  48  -  60 ------------------------------------------------------------------------------
# Capital cumulé :  14718,18
# Intérêts cumulés :  14208,71
# ---------------------------------------------------------------------------------------------------------
#
# ╒════════════╤══════════════╤════════════╤════════════╤═══════════╤════════════╤═══════════╤════════════╕
# │   Echéance │ Mensualité   │ Capital    │ Intérêts   │ Capital   │ Intérêts   │ Capital   │ Intérêts   │
# │            │ échéance     │ échéance   │ échéance   │ cumulé    │ cumulé     │ restant   │ restants   │
# ╞════════════╪══════════════╪════════════╪════════════╪═══════════╪════════════╪═══════════╪════════════╡
# │         61 │ 474,21       │ 260,45     │ 213,76     │ 14978,62  │ 14422,48   │ 84772,00  │ 28090,29   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         62 │ 474,21       │ 261,10     │ 213,11     │ 15239,72  │ 14635,59   │ 84510,90  │ 27877,18   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         63 │ 474,21       │ 261,75     │ 212,46     │ 15501,47  │ 14848,05   │ 84249,15  │ 27664,72   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         64 │ 474,21       │ 262,41     │ 211,81     │ 15763,88  │ 15059,86   │ 83986,74  │ 27452,92   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         65 │ 474,21       │ 263,06     │ 211,15     │ 16026,94  │ 15271,00   │ 83723,68  │ 27241,77   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         66 │ 474,21       │ 263,72     │ 210,49     │ 16290,66  │ 15481,50   │ 83459,96  │ 27031,27   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         67 │ 474,21       │ 264,38     │ 209,83     │ 16555,04  │ 15691,33   │ 83195,58  │ 26821,44   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         68 │ 474,21       │ 265,04     │ 209,17     │ 16820,08  │ 15900,50   │ 82930,54  │ 26612,27   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         69 │ 474,21       │ 265,70     │ 208,51     │ 17085,78  │ 16109,01   │ 82664,84  │ 26403,76   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         70 │ 474,21       │ 266,37     │ 207,84     │ 17352,15  │ 16316,85   │ 82398,47  │ 26195,92   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         71 │ 474,21       │ 267,03     │ 207,18     │ 17619,18  │ 16524,03   │ 82131,44  │ 25988,74   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         72 │ 474,21       │ 267,70     │ 206,51     │ 17886,88  │ 16730,54   │ 81863,74  │ 25782,23   │
# ╘════════════╧══════════════╧════════════╧════════════╧═══════════╧════════════╧═══════════╧════════════╛
# Total périodes :  60  -  72 ------------------------------------------------------------------------------
# Capital cumulé :  17886,88
# Intérêts cumulés :  16730,54
# ---------------------------------------------------------------------------------------------------------
#
# ╒════════════╤══════════════╤════════════╤════════════╤═══════════╤════════════╤═══════════╤════════════╕
# │   Echéance │ Mensualité   │ Capital    │ Intérêts   │ Capital   │ Intérêts   │ Capital   │ Intérêts   │
# │            │ échéance     │ échéance   │ échéance   │ cumulé    │ cumulé     │ restant   │ restants   │
# ╞════════════╪══════════════╪════════════╪════════════╪═══════════╪════════════╪═══════════╪════════════╡
# │         73 │ 474,21       │ 268,37     │ 205,84     │ 18155,25  │ 16936,39   │ 81595,37  │ 25576,38   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         74 │ 474,21       │ 269,04     │ 205,17     │ 18424,29  │ 17141,56   │ 81326,33  │ 25371,21   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         75 │ 474,21       │ 269,71     │ 204,50     │ 18694,00  │ 17346,06   │ 81056,62  │ 25166,72   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         76 │ 474,21       │ 270,39     │ 203,82     │ 18964,39  │ 17549,88   │ 80786,23  │ 24962,89   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         77 │ 474,21       │ 271,06     │ 203,15     │ 19235,46  │ 17753,03   │ 80515,17  │ 24759,74   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         78 │ 474,21       │ 271,74     │ 202,47     │ 19507,20  │ 17955,50   │ 80243,43  │ 24557,27   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         79 │ 474,21       │ 272,42     │ 201,79     │ 19779,62  │ 18157,29   │ 79971,01  │ 24355,48   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         80 │ 474,21       │ 273,10     │ 201,11     │ 20052,72  │ 18358,40   │ 79697,91  │ 24154,37   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         81 │ 474,21       │ 273,78     │ 200,43     │ 20326,50  │ 18558,83   │ 79424,12  │ 23953,94   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         82 │ 474,21       │ 274,47     │ 199,74     │ 20600,97  │ 18758,57   │ 79149,65  │ 23754,20   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         83 │ 474,21       │ 275,15     │ 199,06     │ 20876,12  │ 18957,63   │ 78874,50  │ 23555,14   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         84 │ 474,21       │ 275,84     │ 198,37     │ 21151,97  │ 19155,99   │ 78598,66  │ 23356,78   │
# ╘════════════╧══════════════╧════════════╧════════════╧═══════════╧════════════╧═══════════╧════════════╛
# Total périodes :  72  -  84 ------------------------------------------------------------------------------
# Capital cumulé :  21151,97
# Intérêts cumulés :  19155,99
# ---------------------------------------------------------------------------------------------------------
#
# ╒════════════╤══════════════╤════════════╤════════════╤═══════════╤════════════╤═══════════╤════════════╕
# │   Echéance │ Mensualité   │ Capital    │ Intérêts   │ Capital   │ Intérêts   │ Capital   │ Intérêts   │
# │            │ échéance     │ échéance   │ échéance   │ cumulé    │ cumulé     │ restant   │ restants   │
# ╞════════════╪══════════════╪════════════╪════════════╪═══════════╪════════════╪═══════════╪════════════╡
# │         85 │ 474,21       │ 276,53     │ 197,68     │ 21428,50  │ 19353,67   │ 78322,12  │ 23159,10   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         86 │ 474,21       │ 277,22     │ 196,99     │ 21705,72  │ 19550,66   │ 78044,90  │ 22962,11   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         87 │ 474,21       │ 277,92     │ 196,29     │ 21983,64  │ 19746,96   │ 77766,98  │ 22765,81   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         88 │ 474,21       │ 278,61     │ 195,60     │ 22262,25  │ 19942,56   │ 77488,37  │ 22570,21   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         89 │ 474,21       │ 279,31     │ 194,90     │ 22541,56  │ 20137,46   │ 77209,07  │ 22375,31   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         90 │ 474,21       │ 280,01     │ 194,21     │ 22821,56  │ 20331,67   │ 76929,06  │ 22181,11   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         91 │ 474,21       │ 280,71     │ 193,51     │ 23102,27  │ 20525,17   │ 76648,35  │ 21987,60   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         92 │ 474,21       │ 281,41     │ 192,80     │ 23383,68  │ 20717,97   │ 76366,95  │ 21794,80   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         93 │ 474,21       │ 282,11     │ 192,10     │ 23665,79  │ 20910,07   │ 76084,83  │ 21602,70   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         94 │ 474,21       │ 282,82     │ 191,39     │ 23948,61  │ 21101,47   │ 75802,02  │ 21411,30   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         95 │ 474,21       │ 283,52     │ 190,69     │ 24232,13  │ 21292,16   │ 75518,49  │ 21220,61   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         96 │ 474,21       │ 284,23     │ 189,98     │ 24516,36  │ 21482,14   │ 75234,26  │ 21030,64   │
# ╘════════════╧══════════════╧════════════╧════════════╧═══════════╧════════════╧═══════════╧════════════╛
# Total périodes :  84  -  96 ------------------------------------------------------------------------------
# Capital cumulé :  24516,36
# Intérêts cumulés :  21482,14
# ---------------------------------------------------------------------------------------------------------
#
# ╒════════════╤══════════════╤════════════╤════════════╤═══════════╤════════════╤═══════════╤════════════╕
# │   Echéance │ Mensualité   │ Capital    │ Intérêts   │ Capital   │ Intérêts   │ Capital   │ Intérêts   │
# │            │ échéance     │ échéance   │ échéance   │ cumulé    │ cumulé     │ restant   │ restants   │
# ╞════════════╪══════════════╪════════════╪════════════╪═══════════╪════════════╪═══════════╪════════════╡
# │         97 │ 474,21       │ 284,94     │ 189,27     │ 24801,31  │ 21671,40   │ 74949,32  │ 20841,37   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         98 │ 474,21       │ 285,66     │ 188,56     │ 25086,96  │ 21859,96   │ 74663,66  │ 20652,81   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │         99 │ 474,21       │ 286,37     │ 187,84     │ 25373,33  │ 22047,80   │ 74377,29  │ 20464,97   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        100 │ 474,21       │ 287,09     │ 187,13     │ 25660,42  │ 22234,93   │ 74090,21  │ 20277,84   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        101 │ 474,21       │ 287,80     │ 186,41     │ 25948,22  │ 22421,34   │ 73802,40  │ 20091,44   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        102 │ 474,21       │ 288,52     │ 185,69     │ 26236,74  │ 22607,02   │ 73513,88  │ 19905,75   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        103 │ 474,21       │ 289,24     │ 184,97     │ 26525,99  │ 22791,99   │ 73224,64  │ 19720,78   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        104 │ 474,21       │ 289,97     │ 184,24     │ 26815,95  │ 22976,24   │ 72934,67  │ 19536,54   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        105 │ 474,21       │ 290,69     │ 183,52     │ 27106,64  │ 23159,75   │ 72643,98  │ 19353,02   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        106 │ 474,21       │ 291,42     │ 182,79     │ 27398,06  │ 23342,55   │ 72352,56  │ 19170,22   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        107 │ 474,21       │ 292,15     │ 182,06     │ 27690,21  │ 23524,61   │ 72060,41  │ 18988,16   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        108 │ 474,21       │ 292,88     │ 181,33     │ 27983,09  │ 23705,94   │ 71767,53  │ 18806,83   │
# ╘════════════╧══════════════╧════════════╧════════════╧═══════════╧════════════╧═══════════╧════════════╛
# Total périodes :  96  -  108 ------------------------------------------------------------------------------
# Capital cumulé :  27983,09
# Intérêts cumulés :  23705,94
# ---------------------------------------------------------------------------------------------------------
#
# ╒════════════╤══════════════╤════════════╤════════════╤═══════════╤════════════╤═══════════╤════════════╕
# │   Echéance │ Mensualité   │ Capital    │ Intérêts   │ Capital   │ Intérêts   │ Capital   │ Intérêts   │
# │            │ échéance     │ échéance   │ échéance   │ cumulé    │ cumulé     │ restant   │ restants   │
# ╞════════════╪══════════════╪════════════╪════════════╪═══════════╪════════════╪═══════════╪════════════╡
# │        109 │ 474,21       │ 293,61     │ 180,60     │ 28276,70  │ 23886,55   │ 71473,92  │ 18626,22   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        110 │ 474,21       │ 294,34     │ 179,87     │ 28571,04  │ 24066,41   │ 71179,58  │ 18446,36   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        111 │ 474,21       │ 295,08     │ 179,13     │ 28866,12  │ 24245,54   │ 70884,50  │ 18267,23   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        112 │ 474,21       │ 295,82     │ 178,39     │ 29161,94  │ 24423,94   │ 70588,68  │ 18088,83   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        113 │ 474,21       │ 296,56     │ 177,65     │ 29458,50  │ 24601,59   │ 70292,13  │ 17911,18   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        114 │ 474,21       │ 297,30     │ 176,91     │ 29755,80  │ 24778,51   │ 69994,83  │ 17734,27   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        115 │ 474,21       │ 298,04     │ 176,17     │ 30053,84  │ 24954,68   │ 69696,79  │ 17558,10   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        116 │ 474,21       │ 298,79     │ 175,42     │ 30352,62  │ 25130,10   │ 69398,00  │ 17382,67   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        117 │ 474,21       │ 299,53     │ 174,68     │ 30652,16  │ 25304,78   │ 69098,47  │ 17207,99   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        118 │ 474,21       │ 300,28     │ 173,93     │ 30952,44  │ 25478,71   │ 68798,18  │ 17034,06   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        119 │ 474,21       │ 301,03     │ 173,18     │ 31253,47  │ 25651,88   │ 68497,15  │ 16860,89   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        120 │ 474,21       │ 301,79     │ 172,43     │ 31555,26  │ 25824,31   │ 68195,36  │ 16688,46   │
# ╘════════════╧══════════════╧════════════╧════════════╧═══════════╧════════════╧═══════════╧════════════╛
# Total périodes :  108  -  120 ------------------------------------------------------------------------------
# Capital cumulé :  31555,26
# Intérêts cumulés :  25824,31
# ---------------------------------------------------------------------------------------------------------
#
# ╒════════════╤══════════════╤════════════╤════════════╤═══════════╤════════════╤═══════════╤════════════╕
# │   Echéance │ Mensualité   │ Capital    │ Intérêts   │ Capital   │ Intérêts   │ Capital   │ Intérêts   │
# │            │ échéance     │ échéance   │ échéance   │ cumulé    │ cumulé     │ restant   │ restants   │
# ╞════════════╪══════════════╪════════════╪════════════╪═══════════╪════════════╪═══════════╪════════════╡
# │        121 │ 474,21       │ 302,54     │ 171,67     │ 31857,80  │ 25995,98   │ 67892,82  │ 16516,79   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        122 │ 474,21       │ 303,30     │ 170,91     │ 32161,10  │ 26166,90   │ 67589,53  │ 16345,88   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        123 │ 474,21       │ 304,05     │ 170,16     │ 32465,15  │ 26337,05   │ 67285,47  │ 16175,72   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        124 │ 474,21       │ 304,82     │ 169,40     │ 32769,97  │ 26506,45   │ 66980,66  │ 16006,32   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        125 │ 474,21       │ 305,58     │ 168,63     │ 33075,54  │ 26675,08   │ 66675,08  │ 15837,69   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        126 │ 474,21       │ 306,34     │ 167,87     │ 33381,88  │ 26842,95   │ 66368,74  │ 15669,82   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        127 │ 474,21       │ 307,11     │ 167,10     │ 33688,99  │ 27010,06   │ 66061,63  │ 15502,71   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        128 │ 474,21       │ 307,87     │ 166,34     │ 33996,87  │ 27176,39   │ 65753,76  │ 15336,38   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        129 │ 474,21       │ 308,64     │ 165,57     │ 34305,51  │ 27341,96   │ 65445,11  │ 15170,81   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        130 │ 474,21       │ 309,42     │ 164,80     │ 34614,93  │ 27506,76   │ 65135,70  │ 15006,01   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        131 │ 474,21       │ 310,19     │ 164,02     │ 34925,12  │ 27670,78   │ 64825,51  │ 14841,99   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        132 │ 474,21       │ 310,96     │ 163,25     │ 35236,08  │ 27834,02   │ 64514,54  │ 14678,75   │
# ╘════════════╧══════════════╧════════════╧════════════╧═══════════╧════════════╧═══════════╧════════════╛
# Total périodes :  120  -  132 ------------------------------------------------------------------------------
# Capital cumulé :  35236,08
# Intérêts cumulés :  27834,02
# ---------------------------------------------------------------------------------------------------------
#
# ╒════════════╤══════════════╤════════════╤════════════╤═══════════╤════════════╤═══════════╤════════════╕
# │   Echéance │ Mensualité   │ Capital    │ Intérêts   │ Capital   │ Intérêts   │ Capital   │ Intérêts   │
# │            │ échéance     │ échéance   │ échéance   │ cumulé    │ cumulé     │ restant   │ restants   │
# ╞════════════╪══════════════╪════════════╪════════════╪═══════════╪════════════╪═══════════╪════════════╡
# │        133 │ 474,21       │ 311,74     │ 162,47     │ 35547,82  │ 27996,49   │ 64202,80  │ 14516,28   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        134 │ 474,21       │ 312,52     │ 161,69     │ 35860,34  │ 28158,18   │ 63890,28  │ 14354,59   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        135 │ 474,21       │ 313,30     │ 160,91     │ 36173,65  │ 28319,09   │ 63576,98  │ 14193,68   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        136 │ 474,21       │ 314,09     │ 160,13     │ 36487,73  │ 28479,22   │ 63262,89  │ 14033,55   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        137 │ 474,21       │ 314,87     │ 159,34     │ 36802,61  │ 28638,56   │ 62948,02  │ 13874,22   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        138 │ 474,21       │ 315,66     │ 158,55     │ 37118,26  │ 28797,11   │ 62632,36  │ 13715,66   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        139 │ 474,21       │ 316,45     │ 157,76     │ 37434,71  │ 28954,87   │ 62315,91  │ 13557,90   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        140 │ 474,21       │ 317,24     │ 156,97     │ 37751,95  │ 29111,84   │ 61998,67  │ 13400,93   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        141 │ 474,21       │ 318,03     │ 156,18     │ 38069,98  │ 29268,02   │ 61680,64  │ 13244,75   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        142 │ 474,21       │ 318,83     │ 155,38     │ 38388,81  │ 29423,41   │ 61361,81  │ 13089,36   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        143 │ 474,21       │ 319,62     │ 154,59     │ 38708,43  │ 29577,99   │ 61042,19  │ 12934,78   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        144 │ 474,21       │ 320,42     │ 153,79     │ 39028,86  │ 29731,78   │ 60721,77  │ 12780,99   │
# ╘════════════╧══════════════╧════════════╧════════════╧═══════════╧════════════╧═══════════╧════════════╛
# Total périodes :  132  -  144 ------------------------------------------------------------------------------
# Capital cumulé :  39028,86
# Intérêts cumulés :  29731,78
# ---------------------------------------------------------------------------------------------------------
#
# ╒════════════╤══════════════╤════════════╤════════════╤═══════════╤════════════╤═══════════╤════════════╕
# │   Echéance │ Mensualité   │ Capital    │ Intérêts   │ Capital   │ Intérêts   │ Capital   │ Intérêts   │
# │            │ échéance     │ échéance   │ échéance   │ cumulé    │ cumulé     │ restant   │ restants   │
# ╞════════════╪══════════════╪════════════╪════════════╪═══════════╪════════════╪═══════════╪════════════╡
# │        145 │ 474,21       │ 321,22     │ 152,99     │ 39350,08  │ 29884,77   │ 60400,54  │ 12628,00   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        146 │ 474,21       │ 322,03     │ 152,18     │ 39672,11  │ 30036,95   │ 60078,51  │ 12475,82   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        147 │ 474,21       │ 322,83     │ 151,38     │ 39994,94  │ 30188,33   │ 59755,68  │ 12324,44   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        148 │ 474,21       │ 323,64     │ 150,57     │ 40318,58  │ 30338,90   │ 59432,04  │ 12173,87   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        149 │ 474,21       │ 324,45     │ 149,76     │ 40643,03  │ 30488,67   │ 59107,59  │ 12024,10   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        150 │ 474,21       │ 325,26     │ 148,95     │ 40968,29  │ 30637,62   │ 58782,33  │ 11875,15   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        151 │ 474,21       │ 326,07     │ 148,14     │ 41294,36  │ 30785,76   │ 58456,26  │ 11727,01   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        152 │ 474,21       │ 326,89     │ 147,32     │ 41621,25  │ 30933,08   │ 58129,37  │ 11579,69   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        153 │ 474,21       │ 327,71     │ 146,51     │ 41948,96  │ 31079,59   │ 57801,67  │ 11433,18   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        154 │ 474,21       │ 328,52     │ 145,69     │ 42277,48  │ 31225,27   │ 57473,14  │ 11287,50   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        155 │ 474,21       │ 329,35     │ 144,87     │ 42606,83  │ 31370,14   │ 57143,80  │ 11142,63   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        156 │ 474,21       │ 330,17     │ 144,04     │ 42937,00  │ 31514,18   │ 56813,63  │ 10998,59   │
# ╘════════════╧══════════════╧════════════╧════════════╧═══════════╧════════════╧═══════════╧════════════╛
# Total périodes :  144  -  156 ------------------------------------------------------------------------------
# Capital cumulé :  42937,00
# Intérêts cumulés :  31514,18
# ---------------------------------------------------------------------------------------------------------
#
# ╒════════════╤══════════════╤════════════╤════════════╤═══════════╤════════════╤═══════════╤════════════╕
# │   Echéance │ Mensualité   │ Capital    │ Intérêts   │ Capital   │ Intérêts   │ Capital   │ Intérêts   │
# │            │ échéance     │ échéance   │ échéance   │ cumulé    │ cumulé     │ restant   │ restants   │
# ╞════════════╪══════════════╪════════════╪════════════╪═══════════╪════════════╪═══════════╪════════════╡
# │        157 │ 474,21       │ 330,99     │ 143,22     │ 43267,99  │ 31657,40   │ 56482,63  │ 10855,37   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        158 │ 474,21       │ 331,82     │ 142,39     │ 43599,81  │ 31799,79   │ 56150,81  │ 10712,98   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        159 │ 474,21       │ 332,65     │ 141,56     │ 43932,46  │ 31941,35   │ 55818,16  │ 10571,43   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        160 │ 474,21       │ 333,48     │ 140,73     │ 44265,95  │ 32082,07   │ 55484,68  │ 10430,70   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        161 │ 474,21       │ 334,32     │ 139,89     │ 44600,27  │ 32221,97   │ 55150,36  │ 10290,80   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        162 │ 474,21       │ 335,15     │ 139,06     │ 44935,42  │ 32361,03   │ 54815,21  │ 10151,74   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        163 │ 474,21       │ 335,99     │ 138,22     │ 45271,41  │ 32499,25   │ 54479,21  │ 10013,52   │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        164 │ 474,21       │ 336,83     │ 137,38     │ 45608,24  │ 32636,63   │ 54142,38  │ 9876,14    │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        165 │ 474,21       │ 337,67     │ 136,54     │ 45945,91  │ 32773,17   │ 53804,71  │ 9739,60    │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        166 │ 474,21       │ 338,52     │ 135,69     │ 46284,43  │ 32908,86   │ 53466,19  │ 9603,91    │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        167 │ 474,21       │ 339,36     │ 134,85     │ 46623,79  │ 33043,71   │ 53126,83  │ 9469,06    │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        168 │ 474,21       │ 340,21     │ 134,00     │ 46964,00  │ 33177,71   │ 52786,62  │ 9335,06    │
# ╘════════════╧══════════════╧════════════╧════════════╧═══════════╧════════════╧═══════════╧════════════╛
# Total périodes :  156  -  168 ------------------------------------------------------------------------------
# Capital cumulé :  46964,00
# Intérêts cumulés :  33177,71
# ---------------------------------------------------------------------------------------------------------
#
# ╒════════════╤══════════════╤════════════╤════════════╤═══════════╤════════════╤═══════════╤════════════╕
# │   Echéance │ Mensualité   │ Capital    │ Intérêts   │ Capital   │ Intérêts   │ Capital   │ Intérêts   │
# │            │ échéance     │ échéance   │ échéance   │ cumulé    │ cumulé     │ restant   │ restants   │
# ╞════════════╪══════════════╪════════════╪════════════╪═══════════╪════════════╪═══════════╪════════════╡
# │        169 │ 474,21       │ 341,06     │ 133,15     │ 47305,07  │ 33310,86   │ 52445,56  │ 9201,91    │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        170 │ 474,21       │ 341,91     │ 132,30     │ 47646,98  │ 33443,15   │ 52103,64  │ 9069,62    │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        171 │ 474,21       │ 342,77     │ 131,44     │ 47989,75  │ 33574,60   │ 51760,87  │ 8938,18    │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        172 │ 474,21       │ 343,63     │ 130,58     │ 48333,38  │ 33705,18   │ 51417,25  │ 8807,59    │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        173 │ 474,21       │ 344,49     │ 129,73     │ 48677,86  │ 33834,91   │ 51072,76  │ 8677,86    │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        174 │ 474,21       │ 345,35     │ 128,86     │ 49023,21  │ 33963,77   │ 50727,41  │ 8549,00    │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        175 │ 474,21       │ 346,21     │ 128,00     │ 49369,42  │ 34091,77   │ 50381,20  │ 8421,00    │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        176 │ 474,21       │ 347,08     │ 127,14     │ 49716,50  │ 34218,91   │ 50034,13  │ 8293,86    │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        177 │ 474,21       │ 347,94     │ 126,27     │ 50064,44  │ 34345,17   │ 49686,18  │ 8167,60    │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        178 │ 474,21       │ 348,81     │ 125,40     │ 50413,25  │ 34470,57   │ 49337,37  │ 8042,20    │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        179 │ 474,21       │ 349,69     │ 124,53     │ 50762,94  │ 34595,10   │ 48987,69  │ 7917,67    │
# ...
# │            │ échéance     │ échéance   │ échéance   │ cumulé    │ cumulé     │ restant   │ restants   │
# ╞════════════╪══════════════╪════════════╪════════════╪═══════════╪════════════╪═══════════╪════════════╡
# │        229 │ 474,21       │ 396,18     │ 78,03      │ 69408,74  │ 39659,87   │ 30341,89  │ 2852,91    │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        230 │ 474,21       │ 397,17     │ 77,04      │ 69805,91  │ 39736,90   │ 29944,71  │ 2775,87    │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        231 │ 474,21       │ 398,17     │ 76,04      │ 70204,08  │ 39812,95   │ 29546,55  │ 2699,82    │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        232 │ 474,21       │ 399,16     │ 75,05      │ 70603,24  │ 39888,00   │ 29147,38  │ 2624,78    │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        233 │ 474,21       │ 400,16     │ 74,05      │ 71003,40  │ 39962,05   │ 28747,22  │ 2550,72    │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        234 │ 474,21       │ 401,16     │ 73,05      │ 71404,56  │ 40035,10   │ 28346,06  │ 2477,67    │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        235 │ 474,21       │ 402,16     │ 72,05      │ 71806,73  │ 40107,14   │ 27943,90  │ 2405,63    │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        236 │ 474,21       │ 403,17     │ 71,04      │ 72209,89  │ 40178,19   │ 27540,73  │ 2334,58    │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        237 │ 474,21       │ 404,18     │ 70,03      │ 72614,07  │ 40248,22   │ 27136,55  │ 2264,55    │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        238 │ 474,21       │ 405,19     │ 69,02      │ 73019,26  │ 40317,25   │ 26731,37  │ 2195,53    │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        239 │ 474,21       │ 406,20     │ 68,01      │ 73425,46  │ 40385,26   │ 26325,16  │ 2127,51    │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        240 │ 474,21       │ 407,22     │ 67,00      │ 73832,67  │ 40452,25   │ 25917,95  │ 2060,52    │
# ╘════════════╧══════════════╧════════════╧════════════╧═══════════╧════════════╧═══════════╧════════════╛
# Total périodes :  228  -  240 ------------------------------------------------------------------------------
# Capital cumulé :  73832,67
# Intérêts cumulés :  40452,25
# ---------------------------------------------------------------------------------------------------------
#
# ╒════════════╤══════════════╤════════════╤════════════╤═══════════╤════════════╤═══════════╤════════════╕
# │   Echéance │ Mensualité   │ Capital    │ Intérêts   │ Capital   │ Intérêts   │ Capital   │ Intérêts   │
# │            │ échéance     │ échéance   │ échéance   │ cumulé    │ cumulé     │ restant   │ restants   │
# ╞════════════╪══════════════╪════════════╪════════════╪═══════════╪════════════╪═══════════╪════════════╡
# │        241 │ 474,21       │ 408,23     │ 65,98      │ 74240,91  │ 40518,23   │ 25509,72  │ 1994,54    │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        242 │ 474,21       │ 409,25     │ 64,96      │ 74650,16  │ 40583,19   │ 25100,46  │ 1929,58    │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        243 │ 474,21       │ 410,28     │ 63,93      │ 75060,44  │ 40647,12   │ 24690,18  │ 1865,65    │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        244 │ 474,21       │ 411,30     │ 62,91      │ 75471,74  │ 40710,03   │ 24278,88  │ 1802,74    │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        245 │ 474,21       │ 412,33     │ 61,88      │ 75884,08  │ 40771,91   │ 23866,55  │ 1740,86    │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        246 │ 474,21       │ 413,36     │ 60,85      │ 76297,44  │ 40832,76   │ 23453,19  │ 1680,01    │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        247 │ 474,21       │ 414,40     │ 59,82      │ 76711,83  │ 40892,57   │ 23038,79  │ 1620,20    │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        248 │ 474,21       │ 415,43     │ 58,78      │ 77127,27  │ 40951,35   │ 22623,36  │ 1561,42    │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        249 │ 474,21       │ 416,47     │ 57,74      │ 77543,74  │ 41009,09   │ 22206,89  │ 1503,68    │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        250 │ 474,21       │ 417,51     │ 56,70      │ 77961,25  │ 41065,79   │ 21789,38  │ 1446,98    │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        251 │ 474,21       │ 418,56     │ 55,66      │ 78379,80  │ 41121,45   │ 21370,82  │ 1391,32    │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        252 │ 474,21       │ 419,60     │ 54,61      │ 78799,40  │ 41176,06   │ 20951,22  │ 1336,71    │
# ╘════════════╧══════════════╧════════════╧════════════╧═══════════╧════════════╧═══════════╧════════════╛
# Total périodes :  240  -  252 ------------------------------------------------------------------------------
# Capital cumulé :  78799,40
# Intérêts cumulés :  41176,06
# ---------------------------------------------------------------------------------------------------------
#
# ╒════════════╤══════════════╤════════════╤════════════╤═══════════╤════════════╤═══════════╤════════════╕
# │   Echéance │ Mensualité   │ Capital    │ Intérêts   │ Capital   │ Intérêts   │ Capital   │ Intérêts   │
# │            │ échéance     │ échéance   │ échéance   │ cumulé    │ cumulé     │ restant   │ restants   │
# ╞════════════╪══════════════╪════════════╪════════════╪═══════════╪════════════╪═══════════╪════════════╡
# │        253 │ 474,21       │ 420,65     │ 53,56      │ 79220,05  │ 41229,62   │ 20530,57  │ 1283,15    │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        254 │ 474,21       │ 421,70     │ 52,51      │ 79641,76  │ 41282,13   │ 20108,87  │ 1230,64    │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        255 │ 474,21       │ 422,76     │ 51,45      │ 80064,51  │ 41333,58   │ 19686,11  │ 1179,19    │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        256 │ 474,21       │ 423,81     │ 50,40      │ 80488,33  │ 41383,98   │ 19262,30  │ 1128,79    │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        257 │ 474,21       │ 424,87     │ 49,34      │ 80913,20  │ 41433,32   │ 18837,42  │ 1079,45    │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        258 │ 474,21       │ 425,94     │ 48,28      │ 81339,14  │ 41481,60   │ 18411,49  │ 1031,18    │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        259 │ 474,21       │ 427,00     │ 47,21      │ 81766,14  │ 41528,81   │ 17984,49  │ 983,96     │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        260 │ 474,21       │ 428,07     │ 46,14      │ 82194,20  │ 41574,95   │ 17556,42  │ 937,82     │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        261 │ 474,21       │ 429,14     │ 45,07      │ 82623,34  │ 41620,02   │ 17127,28  │ 892,75     │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        262 │ 474,21       │ 430,21     │ 44,00      │ 83053,55  │ 41664,02   │ 16697,07  │ 848,75     │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        263 │ 474,21       │ 431,29     │ 42,93      │ 83484,84  │ 41706,95   │ 16265,79  │ 805,82     │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        264 │ 474,21       │ 432,36     │ 41,85      │ 83917,20  │ 41748,80   │ 15833,42  │ 763,97     │
# ╘════════════╧══════════════╧════════════╧════════════╧═══════════╧════════════╧═══════════╧════════════╛
# Total périodes :  252  -  264 ------------------------------------------------------------------------------
# Capital cumulé :  83917,20
# Intérêts cumulés :  41748,80
# ---------------------------------------------------------------------------------------------------------
#
# ╒════════════╤══════════════╤════════════╤════════════╤═══════════╤════════════╤═══════════╤════════════╕
# │   Echéance │ Mensualité   │ Capital    │ Intérêts   │ Capital   │ Intérêts   │ Capital   │ Intérêts   │
# │            │ échéance     │ échéance   │ échéance   │ cumulé    │ cumulé     │ restant   │ restants   │
# ╞════════════╪══════════════╪════════════╪════════════╪═══════════╪════════════╪═══════════╪════════════╡
# │        265 │ 474,21       │ 433,45     │ 40,77      │ 84350,65  │ 41789,56   │ 15399,98  │ 723,21     │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        266 │ 474,21       │ 434,53     │ 39,68      │ 84785,18  │ 41829,25   │ 14965,45  │ 683,53     │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        267 │ 474,21       │ 435,62     │ 38,60      │ 85220,79  │ 41867,84   │ 14529,83  │ 644,93     │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        268 │ 474,21       │ 436,70     │ 37,51      │ 85657,49  │ 41905,35   │ 14093,13  │ 607,42     │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        269 │ 474,21       │ 437,80     │ 36,42      │ 86095,29  │ 41941,76   │ 13655,33  │ 571,01     │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        270 │ 474,21       │ 438,89     │ 35,32      │ 86534,18  │ 41977,09   │ 13216,44  │ 535,69     │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        271 │ 474,21       │ 439,99     │ 34,22      │ 86974,17  │ 42011,31   │ 12776,45  │ 501,46     │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        272 │ 474,21       │ 441,09     │ 33,12      │ 87415,26  │ 42044,43   │ 12335,37  │ 468,34     │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        273 │ 474,21       │ 442,19     │ 32,02      │ 87857,45  │ 42076,45   │ 11893,18  │ 436,32     │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        274 │ 474,21       │ 443,30     │ 30,92      │ 88300,74  │ 42107,37   │ 11449,88  │ 405,40     │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        275 │ 474,21       │ 444,40     │ 29,81      │ 88745,15  │ 42137,18   │ 11005,48  │ 375,59     │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        276 │ 474,21       │ 445,52     │ 28,70      │ 89190,66  │ 42165,87   │ 10559,96  │ 346,90     │
# ╘════════════╧══════════════╧════════════╧════════════╧═══════════╧════════════╧═══════════╧════════════╛
# Total périodes :  264  -  276 ------------------------------------------------------------------------------
# Capital cumulé :  89190,66
# Intérêts cumulés :  42165,87
# ---------------------------------------------------------------------------------------------------------
#
# ╒════════════╤══════════════╤════════════╤════════════╤═══════════╤════════════╤═══════════╤════════════╕
# │   Echéance │ Mensualité   │ Capital    │ Intérêts   │ Capital   │ Intérêts   │ Capital   │ Intérêts   │
# │            │ échéance     │ échéance   │ échéance   │ cumulé    │ cumulé     │ restant   │ restants   │
# ╞════════════╪══════════════╪════════════╪════════════╪═══════════╪════════════╪═══════════╪════════════╡
# │        277 │ 474,21       │ 446,63     │ 27,58      │ 89637,29  │ 42193,45   │ 10113,33  │ 319,32     │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        278 │ 474,21       │ 447,75     │ 26,47      │ 90085,04  │ 42219,92   │ 9665,59   │ 292,85     │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        279 │ 474,21       │ 448,86     │ 25,35      │ 90533,90  │ 42245,27   │ 9216,72   │ 267,50     │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        280 │ 474,21       │ 449,99     │ 24,22      │ 90983,89  │ 42269,49   │ 8766,74   │ 243,28     │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        281 │ 474,21       │ 451,11     │ 23,10      │ 91435,00  │ 42292,59   │ 8315,62   │ 220,18     │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        282 │ 474,21       │ 452,24     │ 21,97      │ 91887,24  │ 42314,56   │ 7863,38   │ 198,21     │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        283 │ 474,21       │ 453,37     │ 20,84      │ 92340,61  │ 42335,40   │ 7410,01   │ 177,37     │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        284 │ 474,21       │ 454,50     │ 19,71      │ 92795,11  │ 42355,11   │ 6955,51   │ 157,66     │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        285 │ 474,21       │ 455,64     │ 18,57      │ 93250,75  │ 42373,68   │ 6499,87   │ 139,09     │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        286 │ 474,21       │ 456,78     │ 17,43      │ 93707,53  │ 42391,12   │ 6043,09   │ 121,66     │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        287 │ 474,21       │ 457,92     │ 16,29      │ 94165,45  │ 42407,41   │ 5585,17   │ 105,37     │
# ├────────────┼──────────────┼────────────┼────────────┼───────────┼────────────┼───────────┼────────────┤
# │        288 │ 474,21       │ 459,07     │ 15,15      │ 94624,52  │ 42422,55   │ 5126,10   │ 90,22      │
# ╘════════════╧══════════════╧════════════╧════════════╧═══════════╧════════════╧═══════════╧════════════╛
# Total périodes :  276  -  288 ------------------------------------------------------------------------------
# Capital cumulé :  94624,52
# Intérêts cumulés :  42422,55
# ---------------------------------------------------------------------------------------------------------
# 'End'

# %%
def drawgraph(per:list, ipmt:list, ppmt:list, pmt:list):
    """ Draw a graph of periodic figures

    Args:
        per (list): list of periods
        ipmt (list): list of periodic interests
        ppmt (list): list of periodic capital
        pmt (list): list of periodic payments
    """

    fig, ax = plt.subplots(figsize=(8,8))

    colors = ['#85c1e9', '#f8c471']
    per_max = int(max(per))
    pmt_max = int(np.sum(pmt))
    ipmt_max = int(np.round(np.sum(ipmt)))
    ppmt_max = int(np.round(np.sum(ppmt)))
    pmt_50 = int(np.round(pmt_max * 0.50 , 0))
    pmt_75 = int(np.round(pmt_max * 0.75 , 0))
    ipmt_75 = int(np.round(ipmt_max * 0.75 , 0))
    ppmt_75 = int(np.round(ppmt_max * 0.75 , 0))
    per_75 = int(np.round(per_max * 0.75 , 0))

    ax.plot(ipmt, label='interest', alpha=0.5, linewidth=4, color=colors[1])
    ax.plot(ppmt, label='capital', alpha=0.8, linewidth=4, color=colors[0])

    plt.xlabel('Periods')
    plt.ylabel('Amount')
    plt.legend()
    plt.title('Loan evolution')
    plt.show();
    
    return

def drawgraphcum(per:list, ipmt:list, ppmt:list, pmt:list):
    """ Draw a graph of a cumulated values 

    Args:
        per (list): list of periods
        ipmt (list): list of periodic interests
        ppmt (list): list of periodic capital
        pmt (list): list of periodic payments
    """

    fig, ax = plt.subplots(figsize=(8,8))

    colors = ['#85c1e9', '#f8c471']
    per_max = int(max(per))
    pmt_max = int(np.sum(pmt))
    ipmt_max = int(np.round(np.sum(ipmt)))
    ppmt_max = int(np.round(np.sum(ppmt)))
    pmt_75 = int(np.round(pmt_max * 0.75 , 0))
    ppmt_75 = int(np.round(ppmt_max * 0.75 , 0))
    per_75 = int(np.round(per_max * 0.75 , 0))
    
    per_ipmt_target = find_per_cumul_interest(per=per, ipmt=ipmt, threshold=0.5)

    ax.fill_between(per, np.cumsum(pmt), label='interest', alpha=0.5, linewidth=4, color=colors[1])
    ax.fill_between(per, np.cumsum(ppmt), label='capital', alpha=0.8, linewidth=4, color=colors[0])

    ax.annotate('Capital', (per_75, ppmt_75), size=12, color='white', weight='bold', bbox=dict(boxstyle='round', color=colors[0], pad=0.6))
    ax.annotate('Interest', (per_75, pmt_75), size=12, color='white', weight='bold', bbox=dict(boxstyle='round', color=colors[1], pad=0.6))

    ax.axvline(x=per_ipmt_target, color='#D3D3D3', linestyle='--')

    plt.xlabel('Periods')
    plt.ylabel('Amount')
    #plt.legend()
    plt.title('Loan evolution')
    plt.show();
    
    return

# %%
#drawgraph(per=list_per, ipmt=list_ipmt, ppmt=list_ppmt, pmt=list_pmt)
drawgraphcum(per=list_per, ipmt=list_ipmt, ppmt=list_ppmt, pmt=list_pmt)
